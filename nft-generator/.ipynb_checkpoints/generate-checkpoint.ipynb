# %%
from PIL import Image 
from IPython.display import display 
import random
import json

# %%
# Each image is made up a series of traits
# The weightings for each trait drive the rarity and add up to 100%


background = [
    "Planet Elon",
    "Web3 Mars",
    "Crypto Moon",
    "DeFi Asteroids",
    "DAO Polaris",
    "NFT Pandora",
    "GameFi Neptune",
    "Blockchain Jupiter",
    "Neverland",
]
accessories_eyewear = [
    "No Eyewear",
    "Green Sci-fi Eyewear",
    "Grey Sci-fi Eyewear",
    "Blue LED Eyewear",
    "Silver LED Eyewear",
    "Yellow LED Eyewear",
    "Gold Scholar Eyewear",
    "Purple Scholar Eyewear"
]
hair_front = [
    "Bald",
    "Purple Fringe Hair",
    "Pink Fringe Hair",
    "Red Fringe Hair",
    "Green Fringe Hair",
    "Silver Fringe Hair",
    "Silver Curl Hair",
    "Blue Curl Hair",
    "Green Curl Hair",
    "Silver Curl Hair with Butterfly Hair Accessories",
    "Blue Curl Hair with Butterfly Hair Accessories",
    "Blue Wavy Hair",
    "Blond Wavy Hair",
    "Red Wavy Hair",
    "Black Afro Hair",
    "Brown Afro Hair",
    "Black Afro Hair with Loop Hair Accessories",
    "Blue Afro Hair with Loop Hair Accessories",
    "Brown Afro Hair with Loop Hair Accessories",
    "Silver Circle Hair",
    "Colourful Circle Hair",
    "Burgundy Circle Hair",
    "Blue Circle Hair",
    "Silver A Zone Helmet",
    "Brown Patterned A Zone Helmet",
    "Purple A Zone Helmet",
    "Purple Patterned A Zone Helmet",
]
accessories_earring = [
    "No Earring",
    "Colourful ATEM Earring",
    "Blue ATEM Earring",
    "Pink ATEM Earring",
    "Gold Stud Earring",
    "Red Stud Earring",

]
accessories_cuff = [
    "No Cuff",
    "Colourful Chain Ear Cuff",
    "Silver Chain Ear Cuff",
    "Gold Chain Ear Cuff",
    "Silver Star Nose Cuff",
    "Blue Star Nose Cuff",
]
accessories_necklace = [
    "No Necklace",
    "Gold ATEM Watch Necklace",
    "Green ATEM Watch Necklace",
    "Silver ATEM Watch Necklace",
    "Red ATEM Watch Necklace",
    "Blue Pearl Necklace",
    "Pink Pearl Necklace",
    "White Pearl Necklace",
]
eyebrow = [
    "No Eyebrow",
    "Rock Eyebrow",
    "Dark Spider Eyelash",
    "Light Spider Eyelash",
    "Silver Dragon Eyebrow",
    "Gold Dragon Eyebrow",
    "Red Dragon Eyebrow",
    "Light Ninja Eyebrow",
    "Dark Ninja Eyebrow",
    "Purple Fire Eyelash",
    "Silver Fire Eyelash",
    "Lightning Drop",
]
eye_left = [
    "Desert Eyes Left",
    "Mars Eyes Left",
    "Ocean Eyes Left",
    "Volcano Eyes Left",
    "Aurora Eyes Left",
    "Sun Eyes Left",
    "Kaleidoscope Eyes Left",
    "Star Eyes Left",
    "Loving Eyes Left",
    "Voyager  Eyes Left",
    "Inky Eyes Left",
    "Microgravity Eyes Left",
]
eye_right = [
    "Desert Eyes Right",
    "Mars Eyes Right",
    "Ocean Eyes Right",
    "Volcano Eyes Right",
    "Aurora Eyes Right",
    "Sun Eyes Right",
    "Kaleidoscope Eyes Right",
    "Star Eyes Right",
    "Loving Eyes Right",
    "Voyager  Eyes Right",
    "Inky Eyes Right",
    "Microgravity Eyes Right",
]
eye_cloth = [
    "Black Rock Leather Jacket",
    "White Rock Leather Jacket",
    "Black Fur Dress",
    "Purple Fur Dress",
    "Orange Fur Dress",
    "Grey Fur Hoodie",
    "Burgundy Fur Hoodie",
    "Green Fur Hoodie",
    "Blue ATEM Sport Top",
    "Red ATEM Sport Top",
    "Purple ATEM T-shirt",
    "Red ATEM T-shirt",
    "Orange ATEM T-shirt",
    "Gold Gem Suit",
    "Green Gem Suit",
    "Purple Gem Suit",
]
eye_skin = [
    "Elon Dark Skin",
    "Elon Beige Skin",
    "Elon Bright Skin",
    "Mars Traveler Skin",
    "Mars Capital Skin",
    "Moon Vision Skin",
    "Moon Crater Skin",
    "Asteroids Skin",
    "Polaris Skin",
    "Pandora Skin",
    "Neptune Passenger Skin",
    "AKA Blockchain Jupiter Skin",
    "Neverland Unicorn Skin",
    "Neverland Elf Skin",
]
hair_back = [
    "Bald Back",
    "Purple Fringe Hair Back",
    "Pink Fringe Hair Back",
    "Red Fringe Hair Back",
    "Green Fringe Hair Back",
    "Silver Fringe Hair Back",
    "Silver Curl Hair Back",
    "Blue Curl Hair Back",
    "Green Curl Hair Back",
    "Silver Curl Hair with Butterfly Hair Accessories Back",
    "Blue Curl Hair with Butterfly Hair Accessories Back",
    "Blue Wavy Hair Back",
    "Blond Wavy Hair Back",
    "Red Wavy Hair Back",
    "Black Afro Hair Back",
    "Brown Afro Hair Back",
    "Black Afro Hair with Loop Hair Accessories Back",
    "Blue Afro Hair with Loop Hair Accessories Back",
    "Brown Afro Hair with Loop Hair Accessories Back",
    "Silver Circle Hair Back",
    "Colourful Circle Hair Back",
    "Burgundy Circle Hair Back",
    "Blue Circle Hair Back",
    "Silver A Zone Helmet Back",
    "Brown Patterned A Zone Helmet Back",
    "Purple A Zone Helmet Back",
    "Purple Patterned A Zone Helmet Back",
]

# Dictionary variable for each trait. 
# Eech trait corresponds to its file name


background_files = {
    "Planet Elon": "B_01",
    "Web3 Mars": "B_02",
    "Crypto Moon": "B_03",
    "DeFi Asteroids": "B_04",
    "DAO Polaris": "B_05",
    "NFT Pandora": "B_06",
    "GameFi Neptune": "B_07",
    "Blockchain Jupiter": "B_08",
    "Neverland": "B_09"
}
accessories_eyewear_files = {
    "No Eyewear": "AE_00",
    "Green Sci-fi Eyewear": "AE_01_1",
    "Grey Sci-fi Eyewear": "AE_01_2",
    "Blue LED Eyewear": "AE_02_1",
    "Silver LED Eyewear": "AE_02_2",
    "Yellow LED Eyewear": "AE_02_3",
    "Gold Scholar Eyewear": "AE_03_1",
    "Purple Scholar Eyewear": "AE_03_2",
}
hair_front_files = {
    "Bald": "HF_00",
    "Purple Fringe Hair": "HF_01_1",
    "Pink Fringe Hair": "HF_01_2",
    "Red Fringe Hair": "HF_01_3",
    "Green Fringe Hair": "HF_01_4",
    "Silver Fringe Hair": "HF_01_5",
    "Silver Curl Hair": "HF_02_1",
    "Blue Curl Hair": "HF_02_2",
    "Green Curl Hair": "HF_02_3",
    "Silver Curl Hair with Butterfly Hair Accessories": "HF_03_1",
    "Blue Curl Hair with Butterfly Hair Accessories": "HF_03_2",
    "Blue Wavy Hair": "HF_04_1",
    "Blond Wavy Hair": "HF_04_2",
    "Red Wavy Hair": "HF_04_3",
    "Black Afro Hair": "HF_05_1",
    "Brown Afro Hair": "HF_05_2",
    "Black Afro Hair with Loop Hair Accessories": "HF_06_1",
    "Blue Afro Hair with Loop Hair Accessories": "HF_06_2",
    "Brown Afro Hair with Loop Hair Accessories": "HF_06_3",
    "Silver Circle Hair": "HF_07_1",
    "Colourful Circle Hair": "HF_07_2",
    "Burgundy Circle Hair": "HF_07_3",
    "Blue Circle Hair": "HF_07_4",
    "Silver A Zone Helmet": "HF_08_1",
    "Brown Patterned A Zone Helmet": "HF_08_2",
    "Purple A Zone Helmet": "HF_08_3",
    "Purple Patterned A Zone Helmet": "HF_08_4",
}
accessories_earring_files = {
    "No Earring": "AR_00",
    "Colourful ATEM Earring": "AR_01_1",
    "Blue ATEM Earring": "AR_01_2",
    "Pink ATEM Earring": "AR_01_3",
    "Gold Stud Earring": "AR_02_1",
    "Red Stud Earring": "AR_02_2",

}
accessories_cuff_files = {
    "No Cuff": "AC_00",
    "Colourful Chain Ear Cuff": "AC_01_1",
    "Silver Chain Ear Cuff": "AC_01_2",
    "Gold Chain Ear Cuff": "AC_01_3",
    "Silver Star Nose Cuff": "AC_02_1",
    "Blue Star Nose Cuff": "AC_02_2",
}
accessories_necklace_files = {
    "No Necklace": "AN_00",
    "Gold ATEM Watch Necklace": "AN_01_1",
    "Green ATEM Watch Necklace": "AN_01_2",
    "Silver ATEM Watch Necklace": "AN_01_3",
    "Red ATEM Watch Necklace": "AN_01_4",
    "Blue Pearl Necklace": "AN_02_1",
    "Pink Pearl Necklace": "AN_02_2",
    "White Pearl Necklace": "AN_02_3",
}
eyebrow_files = {
    "No Eyebrow": "EB_00",
    "Rock Eyebrow": "EB_01",
    "Dark Spider Eyelash": "EB_02_1",
    "Light Spider Eyelash": "EB_02_2",
    "Silver Dragon Eyebrow": "EB_03_1",
    "Gold Dragon Eyebrow": "EB_03_2",
    "Red Dragon Eyebrow": "EB_03_3",
    "Light Ninja Eyebrow": "EB_04_1",
    "Dark Ninja Eyebrow": "EB_04_1",
    "Purple Fire Eyelash": "EB_05_1",
    "Silver Fire Eyelash": "EB_05_1",
    "Lightning Drop": "EB_06",
}
eye_left_files = {
    "Desert Eyes Left": "EL_01",
    "Mars Eyes Left": "EL_02",
    "Ocean Eyes Left": "EL_03",
    "Volcano Eyes Left": "EL_04",
    "Aurora Eyes Left": "EL_05",
    "Sun Eyes Left": "EL_06",
    "Kaleidoscope Eyes Left": "EL_07",
    "Star Eyes Left": "EL_08",
    "Loving Eyes Left": "EL_09",
    "Voyager  Eyes Left": "EL_10",
    "Inky Eyes Left": "EL_11",
    "Microgravity Eyes Left": "EL_12",
}
eye_right_files = {
    "Desert Eyes Right": "ER_01",
    "Mars Eyes Right": "ER_02",
    "Ocean Eyes Right": "ER_03",
    "Volcano Eyes Right": "ER_04",
    "Aurora Eyes Right": "ER_05",
    "Sun Eyes Right": "ER_06",
    "Kaleidoscope Eyes Right": "ER_07",
    "Star Eyes Right": "ER_08",
    "Loving Eyes Right": "ER_09",
    "Voyager  Eyes Right": "ER_10",
    "Inky Eyes Right": "ER_11",
    "Microgravity Eyes Right": "ER_12",
}
eye_cloth_files = {
    "Black Rock Leather Jacket": "C_01_1",
    "White Rock Leather Jacket": "C_01_2",
    "Black Fur Dress": "C_02_1",
    "Purple Fur Dress": "C_02_2",
    "Orange Fur Dress": "C_02_3",
    "Grey Fur Hoodie": "C_03_1",
    "Burgundy Fur Hoodie": "C_03_2",
    "Green Fur Hoodie": "C_03_3",
    "Blue ATEM Sport Top": "C_04_1",
    "Red ATEM Sport Top": "C_04_2",
    "Purple ATEM T-shirt": "C_05_1",
    "Red ATEM T-shirt": "C_05_2",
    "Orange ATEM T-shirt": "C_05_3",
    "Gold Gem Suit": "C_06_1",
    "Green Gem Suit": "C_06_2",
    "Purple Gem Suit": "C_06_3",
}
eye_skin_files = {
    "Elon Dark Skin": "S_01",
    "Elon Beige Skin": "S_02",
    "Elon Bright Skin": "S_03",
    "Mars Traveler Skin": "S_04",
    "Mars Capital Skin": "S_05",
    "Moon Vision Skin": "S_06",
    "Moon Crater Skin": "S_07",
    "Asteroids Skin": "S_08",
    "Polaris Skin": "S_09",
    "Pandora Skin": "S_10",
    "Neptune Passenger Skin": "S_11",
    "AKA Blockchain Jupiter Skin": "S_12",
    "Neverland Unicorn Skin": "S_13",
    "Neverland Elf Skin": "S_14",
}
hair_back_files = {
    "Bald Back": "HB_00",
    "Purple Fringe Hair Back": "HB_01_1",
    "Pink Fringe Hair Back": "HB_01_2",
    "Red Fringe Hair Back": "HB_01_3",
    "Green Fringe Hair Back": "HB_01_4",
    "Silver Fringe Hair Back": "HB_02_1",
    "Silver Curl Hair Back": "HB_02_2",
    "Blue Curl Hair Back": "HB_02_3",
    "Green Curl Hair Back": "HB_03_1",
    "Silver Curl Hair with Butterfly Hair Accessories Back": "HB_03_2",
    "Blue Curl Hair with Butterfly Hair Accessories Back": "HB_04_1",
    "Blue Wavy Hair Back": "HB_04_2",
    "Blond Wavy Hair Back": "HB_04_3",
    "Red Wavy Hair Back": "HB_05_1",
    "Black Afro Hair Back": "HB_05_2",
    "Brown Afro Hair Back": "HB_06_1",
    "Black Afro Hair with Loop Hair Accessories Back": "HB_06_2",
    "Blue Afro Hair with Loop Hair Accessories Back": "HB_06_3",
    "Brown Afro Hair with Loop Hair Accessories Back": "HB_07_1",
    "Silver Circle Hair Back": "HB_07_2",
    "Colourful Circle Hair Back": "HB_07_3",
    "Burgundy Circle Hair Back": "HB_07_4",
    "Blue Circle Hair Back": "HB_07_5",
    "Silver A Zone Helmet Back": "HB_08_1",
    "Brown Patterned A Zone Helmet Back": "HB_08_2",
    "Purple A Zone Helmet Back": "HB_08_3",
    "Purple Patterned A Zone Helmet Back": "HB_08_4",
}

# %%
## Generate Traits

TOTAL_IMAGES = 5000 # Number of random unique images we want to generate

all_images = [] 

# A recursive function to generate unique image combinations
def create_new_image():
    
    new_image = {} #

    # For each trait category, select a random trait based on the weightings 
    new_image ["Background"] = random.choices(background)[0]
    new_image ["accessories_eyewear"] = random.choices(accessories_eyewear)[0]
    new_image ["hair_front"] = random.choices(hair_front)[0]
    new_image ["accessories_earring"] = random.choices(accessories_earring)[0]
    new_image ["accessories_cuff"] = random.choices(accessories_cuff)[0]
    new_image ["accessories_necklace"] = random.choices(accessories_necklace)[0]
    new_image ["eyebrow"] = random.choices(eyebrow)[0]
    new_image ["eye_left"] = random.choices(eye_left)[0]
    new_image ["eye_right"] = random.choices(eye_right)[0]
    new_image ["eye_cloth"] = random.choices(eye_cloth)[0]
    new_image ["eye_skin"] = random.choices(eye_skin)[0]
    new_image ["hair_back"] = random.choices(hair_back)[0]
    
    if new_image in all_images:
        return create_new_image()
    else:
        return new_image
    
    
# Generate the unique combinations based on trait weightings
for i in range(TOTAL_IMAGES): 
    
    new_trait_image = create_new_image()
    
    all_images.append(new_trait_image)

# %%
# Returns true if all images are unique
def all_images_unique(all_images):
    seen = list()
    return not any(i in seen or seen.append(i) for i in all_images)

print("Are all images unique?", all_images_unique(all_images))
# Out:
# Are all images unique? True

# %%
# Add token Id to each image
i = 0
for item in all_images:
    item["tokenId"] = i
    i = i + 1

# %%
print(all_images)
# Out:
# [{'Background': 'Blockchain Jupiter', 'accessories_eyewear': 'Purple Scholar Eyewear', 'hair_front': 'Purple Patterned A Zone Helmet', 'accessories_earring': 'Red Stud Earring', 'accessories_cuff': 'Gold Chain Ear Cuff', 'accessories_necklace': 'Red ATEM Watch Necklace', 'eyebrow': 'Light Spider Eyelash', 'eye_left': 'Loving Eyes Left', 'eye_right': 'Mars Eyes Right', 'eye_cloth': 'Burgundy Fur Hoodie', 'eye_skin': 'Asteroids Skin', 'hair_back': 'Purple Patterned A Zone Helmet Back', 'tokenId': 0}, {'Background': 'Web3 Mars', 'accessories_eyewear': 'Green Sci-fi Eyewear', 'hair_front': 'Pink Fringe Hair', 'accessories_earring': 'No Earring', 'accessories_cuff': 'Silver Star Nose Cuff', 'accessories_necklace': 'Green ATEM Watch Necklace', 'eyebrow': 'No Eyebrow', 'eye_left': 'Aurora Eyes Left', 'eye_right': 'Aurora Eyes Right', 'eye_cloth': 'Green Fur Hoodie', 'eye_skin': 'Mars Traveler Skin', 'hair_back': 'Pink Fringe Hair Back', 'tokenId': 1}, {'Background': 'Neverland', 'accessorie
# ...

# %%
# Get Trait Counts

background_count = {}
for item in background:
    background_count[item] = 0
    
accessories_eyewear_count = {}
for item in accessories_eyewear:
    accessories_eyewear_count[item] = 0

hair_front_count = {}
for item in hair_front:
    hair_front_count[item] = 0
accessories_earring_count = {}
for item in accessories_earring:
    accessories_earring_count[item] = 0
accessories_cuff_count = {}
for item in accessories_cuff:
    accessories_cuff_count[item] = 0
accessories_necklace_count = {}
for item in accessories_necklace:
    accessories_necklace_count[item] = 0
eyebrow_count = {}
for item in eyebrow:
    eyebrow_count[item] = 0
eye_left_count = {}
for item in eye_left:
    eye_left_count[item] = 0
eye_right_count = {}
for item in eye_right:
    eye_right_count[item] = 0
eye_cloth_count = {}
for item in eye_cloth:
    eye_cloth_count[item] = 0
eye_skin_count = {}
for item in eye_skin:
    eye_skin_count[item] = 0
hair_back_count = {}
for item in hair_back:
    hair_back_count[item] = 0

for image in all_images:
    background_count[image["Background"]] += 1
    accessories_eyewear_count[image["accessories_eyewear"]] += 1
    hair_front_count[image["hair_front"]] += 1
    accessories_earring_count[image["accessories_earring"]] += 1
    accessories_cuff_count[image["accessories_cuff"]] += 1
    accessories_necklace_count[image["accessories_necklace"]] += 1
    eyebrow_count[image["eyebrow"]] += 1
    eye_left_count[image["eye_left"]] += 1
    eye_right_count[image["eye_right"]] += 1
    eye_cloth_count[image["eye_cloth"]] += 1
    eye_skin_count[image["eye_skin"]] += 1
    hair_back_count[image["hair_back"]] += 1
    
print(background_count)
print(accessories_eyewear_count)
print(hair_front_count)
print(accessories_earring_count)
print(accessories_cuff_count)
print(accessories_necklace_count)
print(eyebrow_count)
print(eye_left_count)
print(eye_right_count)
print(eye_cloth_count)
print(eye_skin_count)
print(hair_back_count)
# Out:
# {'Planet Elon': 548, 'Web3 Mars': 562, 'Crypto Moon': 581, 'DeFi Asteroids': 558, 'DAO Polaris': 570, 'NFT Pandora': 545, 'GameFi Neptune': 551, 'Blockchain Jupiter': 538, 'Neverland': 547}
# {'No Eyewear': 614, 'Green Sci-fi Eyewear': 628, 'Grey Sci-fi Eyewear': 622, 'Blue LED Eyewear': 631, 'Silver LED Eyewear': 613, 'Yellow LED Eyewear': 632, 'Gold Scholar Eyewear': 642, 'Purple Scholar Eyewear': 618}
# ...

# %%
#### Generate Metadata for all Traits 
METADATA_FILE_NAME = './metadata/all-traits.json'; 
with open(METADATA_FILE_NAME, 'w') as outfile:
    json.dump(all_images, outfile, indent=4)

# %%
  
    
#### Generate Images    
for item in all_images:

    im1 = Image.open(f'./trait-layers/12_Background/{background_files[item["Background"]]}.png').convert('RGBA')
    im2 = Image.open(f'./trait-layers/01_Accessories Eyewear/{accessories_eyewear_files[item["accessories_eyewear"]]}.png').convert('RGBA')
    im3 = Image.open(f'./trait-layers/02_Hair Front/{hair_front_files[item["hair_front"]]}.png').convert('RGBA')
    im4 = Image.open(f'./trait-layers/03_Accessories Earring/{accessories_earring_files[item["accessories_earring"]]}.png').convert('RGBA')
    im5 = Image.open(f'./trait-layers/04_Accessories Cuff/{accessories_cuff_files[item["accessories_cuff"]]}.png').convert('RGBA')
    im6 = Image.open(f'./trait-layers/05_Accessories Necklace/{accessories_necklace_files[item["accessories_necklace"]]}.png').convert('RGBA')
    im7 = Image.open(f'./trait-layers/06_Eyebrow/{eyebrow_files[item["eyebrow"]]}.png').convert('RGBA')
    im8 = Image.open(f'./trait-layers/07_Eye Left/{eye_left_files[item["eye_left"]]}.png').convert('RGBA')
    im9 = Image.open(f'./trait-layers/08_Eye Right/{eye_right_files[item["eye_right"]]}.png').convert('RGBA')
    im10 = Image.open(f'./trait-layers/09_Clothes/{eye_cloth_files[item["eye_cloth"]]}.png').convert('RGBA')
    im11 = Image.open(f'./trait-layers/10_Skin/{eye_skin_files[item["eye_skin"]]}.png').convert('RGBA')
    im12 = Image.open(f'./trait-layers/11_Hair Back/{hair_back_files[item["hair_back"]]}.png').convert('RGBA')

    #Create each composite
    com1 = Image.alpha_composite(im1, im2)
    com2 = Image.alpha_composite(com1, im3)
    com3 = Image.alpha_composite(com2, im4)
    com4 = Image.alpha_composite(com3, im5)
    com5 = Image.alpha_composite(com4, im6)
    com6 = Image.alpha_composite(com5, im7)
    com7 = Image.alpha_composite(com6, im8)
    com8 = Image.alpha_composite(com7, im9)
    com9 = Image.alpha_composite(com8, im10)
    com10 = Image.alpha_composite(com9, im11)
    com11 = Image.alpha_composite(com10, im12)

    #Convert to RGB
    rgb_im = com11.convert('RGB')
    file_name = str(item["tokenId"]) + ".png"
    rgb_im.save("./images/" + file_name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [13], in <module>
#      15 im12 = Image.open(f'./trait-layers/11_Hair Back/{hair_back_files[item["hair_back"]]}.png').convert('RGBA')
#      17 #Create each composite
# ---> 18 com1 = Image.alpha_composite(im1, im2)
#      19 com2 = Image.alpha_composite(com1, im3)
#      20 com3 = Image.alpha_composite(com2, im4)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:3029, in alpha_composite(im1, im2)
#    3027 im1.load()
#    3028 im2.load()
# -> 3029 return im1._new(core.alpha_composite(im1.im, im2.im))
#
# ValueError: images do not match

# %%
#### Generate Metadata for each Image    

f = open('./metadata/all-traits.json',) 
data = json.load(f)


IMAGES_BASE_URI = "ADD_IMAGES_BASE_URI_HERE"
PROJECT_NAME = "ADD_PROJECT_NAME_HERE"

def getAttribute(key, value):
    return {
        "trait_type": key,
        "value": value
    }
for i in data:
    token_id = i['tokenId']
    token = {
        "image": IMAGES_BASE_URI + str(token_id) + '.png',
        "tokenId": token_id,
        "name": PROJECT_NAME + ' ' + str(token_id),
        "attributes": []
    }
    token["attributes"].append(getAttribute("Background", i["Background"]))
    token["attributes"].append(getAttribute("accessories_eyewear", i["accessories_eyewear"]))
    token["attributes"].append(getAttribute("hair_front", i["hair_front"]))
    token["attributes"].append(getAttribute("accessories_earring", i["accessories_earring"]))
    token["attributes"].append(getAttribute("accessories_cuff", i["accessories_cuff"]))
    token["attributes"].append(getAttribute("accessories_necklace", i["accessories_necklace"]))
    token["attributes"].append(getAttribute("eyebrow", i["eyebrow"]))
    token["attributes"].append(getAttribute("eye_left", i["eye_left"]))
    token["attributes"].append(getAttribute("eye_right", i["eye_right"]))
    token["attributes"].append(getAttribute("eye_cloth", i["eye_cloth"]))
    token["attributes"].append(getAttribute("eye_skin", i["eye_skin"]))
    token["attributes"].append(getAttribute("hair_back", i["hair_back"]))

    with open('./metadata/' + str(token_id), 'w') as outfile:
        json.dump(token, outfile, indent=4)
f.close()
